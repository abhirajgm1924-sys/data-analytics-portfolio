# %%
#import libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime

# %%
#connect to websites
URL='https://www.amazon.de/-/en/Data-Analyst-Statistics-T-Shirt-black/dp/B0CPTNM4X8/ref=sr_1_2?crid=3I4XOA00WHFNL&dib=eyJ2IjoiMSJ9.tZtLd9xpO_HEiab-yqiAGprBNpB7cM2Luzyjkvi5Lh7ZIUWHhl7vs6dRZmZ2Not6h-_mtxdxdMpejSdj2XtFBjNgs59iHQ0BAh8u43MXV7jcUfrBBTtUnem4AjExteCvC_bQu_SpZT3sdG1VM3AEIhYFVXOreK_Zdi_UIaWbJFI9avYm67FLitPIMKsDkhQn-aVf6Li8tp_mxHyE0T9YnrloKGmEvqX-QKQfiMj0aHiUBL3FIZzg1nwyv4bvfm4aGxo2Vz7hEbf5ROgYm6lI7YmfDWhWDELy_yKKAfMChSI.ZgneToacI8OijCqZeNqz2_cB_6bfL2-Cse42-cJ42OE&dib_tag=se&keywords=data%2Banalyst%2Bgot+data+tshirt&qid=1773061750&sprefix=data%2Banalyst%2Bgot+data+tshirt%2Caps%2C110&sr=8-2'

headers=headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page=requests.get(URL,headers=headers) #pulling the data from the website

soup1=BeautifulSoup(page.content,"html.parser") #pulling the !DOCTYPEHtml content 

soup2=BeautifulSoup(soup1.prettify(),"html.parser") #structuring the pull - making it look decent

title=soup2.find(id='productTitle').get_text() #pulling the title of desired product

price=soup2.find(class_='aok-offscreen').get_text() #price of the product

print(title)

print(price)

# %%
price=price.strip()[1:]
title=title.strip()

print(title)
print(price)
# Out:
# Got Data? | Data Analyst Statistics T-Shirt, black
# 19.99

# %%
import datetime

today=datetime.date.today()
print(today)
# Out:
# 2026-03-09

# %%
#creating the CSV and importing the data
import csv

header=['Title','Price','Date']
data=[title,price,today]

with open('AmazonWebDataset.csv','w',newline="",encoding='UTF8') as f:
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df=pd.read_csv(r'C:\Users\abhir\OneDrive\Desktop\Data Projects\AmazonWebDataset.csv')

print(df)

# %%
#Appending the data to CSV

with open('AmazonWebDataset.csv','a+',newline="",encoding='UTF8') as f:
    writer=csv.writer(f)
    writer.writerow(data)

# %%
#gathering everything under a single function
def check_price():
    URL='https://www.amazon.de/-/en/Data-Analyst-Statistics-T-Shirt-black/dp/B0CPTNM4X8/ref=sr_1_2?crid=3I4XOA00WHFNL&dib=eyJ2IjoiMSJ9.tZtLd9xpO_HEiab-yqiAGprBNpB7cM2Luzyjkvi5Lh7ZIUWHhl7vs6dRZmZ2Not6h-_mtxdxdMpejSdj2XtFBjNgs59iHQ0BAh8u43MXV7jcUfrBBTtUnem4AjExteCvC_bQu_SpZT3sdG1VM3AEIhYFVXOreK_Zdi_UIaWbJFI9avYm67FLitPIMKsDkhQn-aVf6Li8tp_mxHyE0T9YnrloKGmEvqX-QKQfiMj0aHiUBL3FIZzg1nwyv4bvfm4aGxo2Vz7hEbf5ROgYm6lI7YmfDWhWDELy_yKKAfMChSI.ZgneToacI8OijCqZeNqz2_cB_6bfL2-Cse42-cJ42OE&dib_tag=se&keywords=data%2Banalyst%2Bgot+data+tshirt&qid=1773061750&sprefix=data%2Banalyst%2Bgot+data+tshirt%2Caps%2C110&sr=8-2'

    headers=headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page=requests.get(URL,headers=headers) #pulling the data from the website

    soup1=BeautifulSoup(page.content,"html.parser") #pulling the !DOCTYPEHtml content 

    soup2=BeautifulSoup(soup1.prettify(),"html.parser") #structuring the pull - making it look decent

    title=soup2.find(id='productTitle').get_text() #pulling the title of desired product

    price=soup2.find(class_='aok-offscreen').get_text() #price of the product

    price=price.strip()[1:]
    title=title.strip()

    import datetime

    today=datetime.date.today()

    import csv

    header=['Title','Price','Date']
    data=[title,price,today]

    with open('AmazonWebDataset.csv','a+',newline="",encoding='UTF8') as f:
        writer=csv.writer(f)
        writer.writerow(data)

# %%
#runs check_price() function once per a day
while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd

df=pd.read_csv(r'C:\Users\abhir\OneDrive\Desktop\Data Projects\AmazonWebDataset.csv')

print(df)
# Out:
#                                                Title  Price        Date
# 0  Got Data? | Data Analyst Statistics T-Shirt, b...  19.99  2026-03-09
# 1  Got Data? | Data Analyst Statistics T-Shirt, b...  19.99  2026-03-09
# 2  Got Data? | Data Analyst Statistics T-Shirt, b...  19.99  2026-03-09
# 3  Got Data? | Data Analyst Statistics T-Shirt, b...  19.99  2026-03-09
# 4  Got Data? | Data Analyst Statistics T-Shirt, b...  19.99  2026-03-09
# 5  Got Data? | Data Analyst Statistics T-Shirt, b...  19.99  2026-03-09

# %%
#plot for visualization of price difference
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("AmazonWebDataset.csv")

df["Price"] = df["Price"].astype(float)

plt.plot(df["Date"], df["Price"],marker='o')

plt.title("Amazon Price Tracker")
plt.xlabel("Date")
plt.ylabel("Price (€)")
plt.xticks(rotation=45)

plt.show()
